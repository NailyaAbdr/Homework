# %% [markdown]
# <a href="https://colab.research.google.com/github/NailyaAbdr/Homework/blob/main/Abdr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Домашнее задание, урок 17**

# %%
import pandas as pd
data = pd.read_csv('employee_data.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   EmpID                       3000 non-null   int64
#  1   FirstName                   3000 non-null   object
#  2   LastName                    3000 non-null   object
#  3   StartDate                   3000 non-null   object
#  4   ExitDate                    1533 non-null   object
#  5   Title                       3000 non-null   object
#  6   Supervisor                  3000 non-null   object
#  7   ADEmail                     3000 non-null   object
#  8   BusinessUnit                3000 non-null   object
#  9   EmployeeStatus              3000 non-null   object
#  10  EmployeeType                3000 non-null   object
#  11  PayZone                     3000 non-null   object
#  12  EmployeeClassificationType  3000 non-null   object
# ...

# %% [markdown]
# В таблице 26 колонок и 3000 строк. Все строки полные кроме ExitDate ((Дата, когда сотрудник покинул организацию(пустых 1467 - 48,9%)) и *TerminationDescription *((Дополнительные сведения или причины увольнения сотрудника (пустых 1467 - 48,9%)).Данные столбцы описывают только сотрудников, уволившихся из компании.

# %%
data.describe()
# Out:
#              EmpID  LocationCode  Current Employee Rating
# count  3000.000000   3000.000000              3000.000000
# mean   2500.500000  44997.180667                 2.969000
# std     866.169729  29987.331783                 1.015078
# min    1001.000000   1013.000000                 1.000000
# 25%    1750.750000  17546.000000                 2.000000
# 50%    2500.500000  44150.500000                 3.000000
# 75%    3250.250000  71481.250000                 3.000000
# max    4000.000000  98052.000000                 5.000000

# %% [markdown]
# У многих данных в столбцах тип "object", что не позволяет сделать их описание. С типом "int64" только три столбца: EmpID, LocationCode, Current Employee Rating. Данные представленных столбцов можно считать представительными, т.к. экстремальных выбросов (max, min) не наблюдается.

# %% [markdown]
# **Домашнее задание, урок 18**

# %% [markdown]
# Из предыдущего задания видно, что пустыми являются только дсва столбца. Выведем их значения

# %%
x = data.isnull()

# %%
x.loc[((x['ExitDate']==True)&(x['TerminationDescription']==True))]
# Out:
#       EmpID  FirstName  LastName  StartDate  ExitDate  Title  Supervisor  \
# 0     False      False     False      False      True  False       False
# 1     False      False     False      False      True  False       False
# 2     False      False     False      False      True  False       False
# 3     False      False     False      False      True  False       False
# 4     False      False     False      False      True  False       False
# ...     ...        ...       ...        ...       ...    ...         ...
# 2990  False      False     False      False      True  False       False
# 2991  False      False     False      False      True  False       False
# 2992  False      False     False      False      True  False       False
# 2996  False      False     False      False      True  False       False
# 2999  False      False     False      False      True  False       False
#
#       ADEmail  BusinessUnit  EmployeeStatus  ...  Division    DOB  State  \
# ...

# %% [markdown]
# Количество пустых строк совпадает с цифрой предыдущего задания (1467)

# %%
data.corr()
# Out:
# <ipython-input-76-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                             EmpID  LocationCode  Current Employee Rating
# EmpID                    1.000000      0.006468                -0.021722
# LocationCode             0.006468      1.000000                -0.022504
# Current Employee Rating -0.021722     -0.022504                 1.000000

# %% [markdown]
# Из предыдущего ДЗ мы помним, что с типом "int64" только три столбца: EmpID, LocationCode, Current Employee Rating.
#
#
# *  EmpID и LocationCode имеют низкую положительную корреляцию, - табельный номер мало зависит от кода локации.
# *   EmpID и Current Employee Rating имеют низкую отрицательную корреляцию, - табельный номер мало зависит от рейтинга сотрудника.
# *   LocationCode и Current Employee Rating имеют низкую отрицательную корреляцию, - код локации мало зависит от рейтинга сотрудника.

# %%
df = data[['EmpID','LocationCode','Current Employee Rating']]
df['Current Employee Rating'].sum()
# Out:
# 8907

# %%
df['Current Employee Rating'].mean()
# Out:
# 2.969

# %%
df['Current Employee Rating'].median()
# Out:
# 3.0

# %%
df['Current Employee Rating'].std()
# Out:
# 1.0150775639429104

# %%
df['Current Employee Rating'].max()
# Out:
# 5

# %%
df['Current Employee Rating'].min()
# Out:
# 1

# %%
df1 = df.loc[0:1499]
df2 = df.loc[1500:3000]
df2.reset_index(drop=True, inplace= True)
print (df1>=df2)
# Out:
#       EmpID  LocationCode  Current Employee Rating
# 0      True          True                     True
# 1      True         False                     True
# 2      True         False                     True
# 3      True         False                    False
# 4      True          True                     True
# ...     ...           ...                      ...
# 1495  False          True                     True
# 1496  False          True                     True
# 1497  False          True                     True
# 1498  False          True                     True
# 1499  False          True                     True
#
# [1500 rows x 3 columns]
